# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
df = pd.read_csv('Master file.csv')
df
# Out:
#     Data Series  TotalFertilityRate(PerFemale)  \
# 0          2022                           1.05
# 1          2021                           1.12
# 2          2020                           1.10
# 3          2019                           1.14
# 4          2018                           1.14
# ..          ...                            ...
# 57         1965                           4.66
# 58         1964                           4.97
# 59         1963                           5.16
# 60         1962                           5.21
# 61         1961                           5.41
#
#     15to19Years(PerThousandFemales)  20to24Years(PerThousandFemales)  \
# 0                               2.1                             11.3
# 1                               2.2                             11.7
# 2                               2.3                             12.7
# 3                               2.5                             12.7
# 4                               2.5                             14.4
# ..                              ...                              ...
# 57                             35.9                            227.1
# 58                             38.3                            240.0
# 59                             45.7                            249.0
# 60                             52.0                            245.5
# 61                             63.4                            241.1
#
#     25to29Years(PerThousandFemales)  30to34Years(PerThousandFemales)  \
# 0                              49.1                             87.1
# 1                              53.4                             92.9
# 2                              54.6                             90.8
# 3                              59.4                             92.4
# 4                              60.6                             92.9
# ..                              ...                              ...
# 57                            259.5                            216.2
# 58                            277.6                            226.7
# 59                            287.2                            228.7
# 60                            291.7                            231.5
# 61                            304.9                            238.4
#
#     35to39Years(PerThousandFemales)  40to44Years(PerThousandFemales)  \
# 0                              49.5                              9.8
# 1                              53.6                             10.2
# 2                              49.0                              9.5
# 3                              50.1                              9.9
# 4                              48.4                              8.8
# ..                              ...                              ...
# 57                            138.1                             54.9
# 58                            147.7                             62.8
# 59                            156.1                             64.9
# 60                            156.2                             65.1
# 61                            168.9                             64.8
#
#    45to49Years(PerThousandFemales)  Chinese(PerFemale)  ...  \
# 0                              0.4                0.87  ...
# 1                              0.3                0.96  ...
# 2                              0.5                0.94  ...
# 3                              0.4                0.99  ...
# 4                              0.5                0.98  ...
# ..                             ...                 ...  ...
# 57                              na                4.31  ...
# 58                              na                4.60  ...
# 59                              na                4.83  ...
# 60                              na                4.92  ...
# 61                              na                5.20  ...
#
#     25to29Years(Per1000UnmarriedResidentFemales)  \
# 0                                          100.9
# 1                                           79.9
# 2                                           88.6
# 3                                           99.8
# 4                                          108.8
# ..                                           ...
# 57                                           NaN
# 58                                           NaN
# 59                                           NaN
# 60                                           NaN
# 61                                           NaN
#
#     30to34Years(Per1000UnmarriedResidentFemales)  \
# 0                                          106.4
# 1                                           81.6
# 2                                           95.5
# 3                                          100.0
# 4                                          101.6
# ..                                           ...
# 57                                           NaN
# 58                                           NaN
# 59                                           NaN
# 60                                           NaN
# 61                                           NaN
#
#    35to39Years(Per1000UnmarriedResidentFemales)  \
# 0                                          49.0
# 1                                          39.9
# 2                                          46.8
# 3                                          48.0
# 4                                          51.2
# ..                                          ...
# 57                                          NaN
# 58                                          NaN
# 59                                          NaN
# 60                                          NaN
# 61                                          NaN
#
#    40to44Years(Per1000UnmarriedResidentFemales)  \
# 0                                          19.2
# 1                                          17.3
# 2                                          21.4
# 3                                          22.0
# 4                                          22.4
# ..                                          ...
# 57                                          NaN
# 58                                          NaN
# 59                                          NaN
# 60                                          NaN
# 61                                          NaN
#
#     45to49Years(Per1000UnmarriedResidentFemales)  \
# 0                                            9.5
# 1                                            9.1
# 2                                           11.0
# 3                                           12.1
# 4                                           12.0
# ..                                           ...
# 57                                           NaN
# 58                                           NaN
# 59                                           NaN
# 60                                           NaN
# 61                                           NaN
#
#     50to54Years(Per1000UnmarriedResidentFemales)  \
# 0                                            6.8
# 1                                            5.6
# 2                                            6.5
# 3                                            6.3
# 4                                            5.6
# ..                                           ...
# 57                                           NaN
# 58                                           NaN
# 59                                           NaN
# 60                                           NaN
# 61                                           NaN
#
#    55to59Years(Per1000UnmarriedResidentFemales)  \
# 0                                           2.8
# 1                                           2.6
# 2                                           3.4
# 3                                           2.8
# 4                                           2.9
# ..                                          ...
# 57                                          NaN
# 58                                          NaN
# 59                                          NaN
# 60                                          NaN
# 61                                          NaN
#
#     60to64Years(Per1000UnmarriedResidentFemales)  \
# 0                                            1.7
# 1                                            1.3
# 2                                            1.5
# 3                                            1.5
# 4                                            1.3
# ..                                           ...
# 57                                           NaN
# 58                                           NaN
# 59                                           NaN
# 60                                           NaN
# 61                                           NaN
#
#     65Years&Over(Per1000UnmarriedResidentFemales)  \
# 0                                             0.3
# 1                                             0.2
# 2                                             0.3
# 3                                             0.2
# 4                                             0.2
# ..                                            ...
# 57                                            NaN
# 58                                            NaN
# 59                                            NaN
# 60                                            NaN
# 61                                            NaN
#
#     CrudeMarriageRate(Per1000Residents)
# 0                                   6.5
# 1                                   5.2
# 2                                   5.9
# 3                                   6.4
# 4                                   6.6
# ..                                  ...
# 57                                  NaN
# 58                                  NaN
# 59                                  NaN
# 60                                  NaN
# 61                                  NaN
#
# [62 rows x 195 columns]

# %%
df.shape
# Out:
# (62, 195)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Columns: 195 entries, Data Series to CrudeMarriageRate(Per1000Residents)
# dtypes: float64(81), int64(2), object(112)
# memory usage: 94.6+ KB

# %%
#Change Header names for easier reading
df = df.rename(columns={'Data Series': 'Years'})

df = df.rename(columns={'TotalFertilityRate(PerFemale)': 'TotalFertilityRate'})
df = df.rename(columns={'15to19Years(PerThousandFemales)': 'F.15to19Years'})
df = df.rename(columns={'20to24Years(PerThousandFemales)': 'F.20to24Years'})
df = df.rename(columns={'25to29Years(PerThousandFemales)': 'F.25to29Years'})
df = df.rename(columns={'30to34Years(PerThousandFemales)': 'F.30to34Years'})
df = df.rename(columns={'35to39Years(PerThousandFemales)': 'F.35to39Years'})
df = df.rename(columns={'40to44Years(PerThousandFemales)': 'F.40to44Years'})
df = df.rename(columns={'45to49Years(PerThousandFemales)': 'F.45to49Years'})


df = df.rename(columns={'TotalFemalestoBelowSecondary': 'BelowSecondary'})
df = df.rename(columns={'TotalFemalestoSecondary': 'Secondary'})
df = df.rename(columns={'TotalFemalestoPostSecondary(NontoTertiary)': 'PostSecondary(NontoTertiary)'})
df = df.rename(columns={'TotalFemalestoDiploma&ProfessionalQualification': 'Diploma&ProfessionalQualification'})
df = df.rename(columns={'TotalFemalestoUniversity': 'University'})


df = df.rename(columns={'FemaleGeneralMarriageRate(Per1000UnmarriedResidentMalesOrFemalesAged15to49Years)': 'FemaleGeneralMarriageRate'})
df = df.rename(columns={'15to19Years(Per1000UnmarriedResidentFemales)': 'M.15to19Years'})
df = df.rename(columns={'20to24Years(Per1000UnmarriedResidentFemales)': 'M.20to24Years'})
df = df.rename(columns={'25to29Years(Per1000UnmarriedResidentFemales)': 'M.25to29Years'})
df = df.rename(columns={'30to34Years(Per1000UnmarriedResidentFemales)': 'M.30to34Years'})
df = df.rename(columns={'35to39Years(Per1000UnmarriedResidentFemales)': 'M.35to39Years'})
df = df.rename(columns={'40to44Years(Per1000UnmarriedResidentFemales)': 'M.40to44Years'})
df = df.rename(columns={'45to49Years(Per1000UnmarriedResidentFemales)': 'M.45to49Years'})
df = df.rename(columns={'50to54Years(Per1000UnmarriedResidentFemales)': 'M.50to54Years'})
df = df.rename(columns={'55to59Years(Per1000UnmarriedResidentFemales)': 'M.55to59Years'})
df = df.rename(columns={'60to64Years(Per1000UnmarriedResidentFemales)': 'M.60to64Years'})
df = df.rename(columns={'65Years&Over(Per1000UnmarriedResidentFemales)': 'M.65Years&Over'})

# %%
#Since the years are in consecutive, we will be using it as the index instead of 0,1,2,3
df = df.set_index('Years')
df
# Out:
#        TotalFertilityRate  F.15to19Years  F.20to24Years  F.25to29Years  \
# Years
# 2022                 1.05            2.1           11.3           49.1
# 2021                 1.12            2.2           11.7           53.4
# 2020                 1.10            2.3           12.7           54.6
# 2019                 1.14            2.5           12.7           59.4
# 2018                 1.14            2.5           14.4           60.6
# ...                   ...            ...            ...            ...
# 1965                 4.66           35.9          227.1          259.5
# 1964                 4.97           38.3          240.0          277.6
# 1963                 5.16           45.7          249.0          287.2
# 1962                 5.21           52.0          245.5          291.7
# 1961                 5.41           63.4          241.1          304.9
#
#        F.30to34Years  F.35to39Years  F.40to44Years F.45to49Years  \
# Years
# 2022            87.1           49.5            9.8           0.4
# 2021            92.9           53.6           10.2           0.3
# 2020            90.8           49.0            9.5           0.5
# 2019            92.4           50.1            9.9           0.4
# 2018            92.9           48.4            8.8           0.5
# ...              ...            ...            ...           ...
# 1965           216.2          138.1           54.9            na
# 1964           226.7          147.7           62.8            na
# 1963           228.7          156.1           64.9            na
# 1962           231.5          156.2           65.1            na
# 1961           238.4          168.9           64.8            na
#
#        Chinese(PerFemale)  Malays(PerFemale)  ...  M.25to29Years  \
# Years                                         ...
# 2022                 0.87               1.83  ...          100.9
# 2021                 0.96               1.82  ...           79.9
# 2020                 0.94               1.82  ...           88.6
# 2019                 0.99               1.80  ...           99.8
# 2018                 0.98               1.85  ...          108.8
# ...                   ...                ...  ...            ...
# 1965                 4.31               6.31  ...            NaN
# 1964                 4.60               6.78  ...            NaN
# 1963                 4.83               6.75  ...            NaN
# 1962                 4.92               6.63  ...            NaN
# 1961                 5.20               6.42  ...            NaN
#
#       M.30to34Years M.35to39Years  M.40to44Years  M.45to49Years M.50to54Years  \
# Years
# 2022          106.4          49.0           19.2            9.5           6.8
# 2021           81.6          39.9           17.3            9.1           5.6
# 2020           95.5          46.8           21.4           11.0           6.5
# 2019          100.0          48.0           22.0           12.1           6.3
# 2018          101.6          51.2           22.4           12.0           5.6
# ...             ...           ...            ...            ...           ...
# 1965            NaN           NaN            NaN            NaN           NaN
# 1964            NaN           NaN            NaN            NaN           NaN
# 1963            NaN           NaN            NaN            NaN           NaN
# 1962            NaN           NaN            NaN            NaN           NaN
# 1961            NaN           NaN            NaN            NaN           NaN
#
#        M.55to59Years  M.60to64Years  M.65Years&Over  \
# Years
# 2022             2.8            1.7             0.3
# 2021             2.6            1.3             0.2
# 2020             3.4            1.5             0.3
# 2019             2.8            1.5             0.2
# 2018             2.9            1.3             0.2
# ...              ...            ...             ...
# 1965             NaN            NaN             NaN
# 1964             NaN            NaN             NaN
# 1963             NaN            NaN             NaN
# 1962             NaN            NaN             NaN
# 1961             NaN            NaN             NaN
#
#        CrudeMarriageRate(Per1000Residents)
# Years
# 2022                                   6.5
# 2021                                   5.2
# 2020                                   5.9
# 2019                                   6.4
# 2018                                   6.6
# ...                                    ...
# 1965                                   NaN
# 1964                                   NaN
# 1963                                   NaN
# 1962                                   NaN
# 1961                                   NaN
#
# [62 rows x 194 columns]

# %% [markdown]
# ## 1. Preliminary Feature Selection
#
# Firstly, we noticed that our dataset contains a lot of variables. Using all of these variables would not be feasible. Hence, we decided to select a subset of the variables and work with this subset.
#
# The choice of the variables has been made carefully. Since our question relates to the conventionality of developers and their success, the variables we have chosen are:
#
# **Main Variables**
# - Years
# - TotalFertilityRate(PerFemale)
#
# **Variables Relating to Fertility(Per 1000 Females):**
#
# - TotalFertilityRate(Per female)
# - 15to19Years
# - 20to24Years
# - 25to29Years
# - 30to34Years
# - 35to39Years
# - 40to44Years
# - 45to49Years
# - 50to54Years
# - 55to59Years
# - 60to64Years
# - 65Years&Over
#
# **Variables Relating to Education:**
#
# - BelowSecondary
# - Secondary
# - PostSecondary(NontoTertiary)
# - Diploma&ProfessionalQualification
# - University
#
# **Variables Relating to Cost of Living:**
#
# - AllItems
# - Food
# - Clothing&Footwear
# - Housing&Utilities
# - HouseholdDurables&Services
# - HouseholdServices&Supplies
# - HealthCare
# - Transport
# - PrivateTransport
# - PublicTransport
# - OtherTransportServices
# - Communication
# - Recreation&Culture
# - Education
# - MiscellaneousGoods&Services
# - PersonalCare
# - AlcoholicDrinks&Tobacco
# - PersonalEffects
# - AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation
# - AllItemsLessAccommodation
#
# **Variables Relating to Marriage(Per1000UnmarriedResidentFemales):**
#
# - FemaleGeneralMarriageRate
# - 15to19Years
# - 20to24Years
# - 25to29Years
# - 30to34Years
# - 35to39Years
# - 40to44Years
# - 45to49Years
# - 50to54Years
# - 55to59Years
# - 60to64Years
# - 65Years&Over

# %%
EduFactor = df[[
      'TotalFertilityRate',
      'BelowSecondary',
      'Secondary',
      'PostSecondary(NontoTertiary)',
      'Diploma&ProfessionalQualification',
      'University']]

EduFactor = EduFactor.dropna()

EduFactor
# Out:
#        TotalFertilityRate  BelowSecondary  Secondary  \
# Years
# 2022                 1.05        369800.0   271500.0
# 2021                 1.12        362700.0   281300.0
# 2020                 1.10        433400.0   269300.0
# 2019                 1.14        426500.0   282800.0
# 2018                 1.14        441500.0   285600.0
# 2017                 1.16        464700.0   271900.0
# 2016                 1.20        469900.0   281800.0
# 2015                 1.24        454900.0   291800.0
# 2014                 1.25        468700.0   285500.0
# 2013                 1.19        472700.0   280600.0
# 2012                 1.29        480100.0   281900.0
# 2011                 1.20        491000.0   285100.0
# 2010                 1.15        499600.0   268300.0
# 2009                 1.22        518900.0   304800.0
# 2008                 1.28        497600.0   307700.0
# 2007                 1.29        538700.0   297800.0
# 2006                 1.28        543900.0   291600.0
# 2005                 1.26        524400.0   256800.0
# 2004                 1.26        551400.0   270900.0
# 2003                 1.27        554300.0   281900.0
# 2002                 1.37        547300.0   287500.0
# 2001                 1.41        545900.0   276300.0
# 2000                 1.60        517300.0   255900.0
# 1999                 1.47        552400.0   269800.0
# 1998                 1.48        554700.0   264400.0
# 1997                 1.61        563700.0   248300.0
# 1996                 1.66        544400.0   250700.0
# 1995                 1.67        531000.0   246200.0
# 1994                 1.71        549700.0   230800.0
# 1993                 1.74        547300.0   217400.0
# 1992                 1.72        543400.0   215400.0
# 1991                 1.73        540100.0   205300.0
# 1990                 1.83        535200.0   191800.0
#
#        PostSecondary(NontoTertiary)  Diploma&ProfessionalQualification  \
# Years
# 2022                       147700.0                           265100.0
# 2021                       130000.0                           239000.0
# 2020                       138800.0                           226700.0
# 2019                       122400.0                           225700.0
# 2018                       117600.0                           215400.0
# 2017                       118200.0                           207300.0
# 2016                       110600.0                           199700.0
# 2015                       113200.0                           200200.0
# 2014                       107800.0                           198200.0
# 2013                       104700.0                           183400.0
# 2012                       107300.0                           177300.0
# 2011                       102900.0                           166100.0
# 2010                       112600.0                           165100.0
# 2009                        72800.0                           149100.0
# 2008                        71600.0                           140500.0
# 2007                        75300.0                           131500.0
# 2006                        74000.0                           122400.0
# 2005                       102800.0                           126400.0
# 2004                        73400.0                           106900.0
# 2003                        72800.0                            99300.0
# 2002                        70600.0                            86100.0
# 2001                        67700.0                            84500.0
# 2000                        91800.0                            91200.0
# 1999                        72100.0                            69600.0
# 1998                        71200.0                            61400.0
# 1997                        68000.0                            49500.0
# 1996                        65100.0                            48000.0
# 1995                        72700.0                            40200.0
# 1994                        59300.0                            33200.0
# 1993                        55700.0                            28000.0
# 1992                        53200.0                            26900.0
# 1991                        50100.0                            21000.0
# 1990                        36700.0                            18900.0
#
#        University
# Years
# 2022     552400.0
# 2021     534200.0
# 2020     496600.0
# 2019     470500.0
# 2018     440400.0
# 2017     420500.0
# 2016     398700.0
# 2015     374800.0
# 2014     362400.0
# 2013     350000.0
# 2012     320700.0
# 2011     307300.0
# 2010     288100.0
# 2009     266400.0
# 2008     246300.0
# 2007     226300.0
# 2006     212700.0
# 2005     180500.0
# 2004     172800.0
# 2003     158600.0
# 2002     140000.0
# 2001     121200.0
# 2000     105100.0
# 1999      94100.0
# 1998      87500.0
# 1997      75500.0
# 1996      69100.0
# 1995      54300.0
# 1994      49600.0
# 1993      44500.0
# 1992      37100.0
# 1991      31400.0
# 1990      28900.0

# %%
MarFactor = df[[
      'TotalFertilityRate',
      'FemaleGeneralMarriageRate',
      'M.15to19Years',
      'M.20to24Years',
      'M.25to29Years',
      'M.30to34Years',
      'M.35to39Years',
      'M.40to44Years',
      'M.45to49Years',
      'M.50to54Years',
      'M.55to59Years',
      'M.60to64Years',
      'M.65Years&Over']]


MarFactor = MarFactor.dropna()
MarFactor = MarFactor.replace('na', 0)
MarFactor = MarFactor.replace(',', '', regex=True)
MarFactor
# Out:
# 1994             0.6            0.1
# 1993             0.4            0.1
# 1992             0.6            0.1
# 1991             0.3            0.1
# 1990             0.7            0.1
# 1989             0.6            0.2
# 1988             0.8            0.1
# 1987             0.4            0.1
# 1986             0.2            0.1
# 1985             0.6            0.1
# 1984             0.2              0
# 1983             0.3              0
# 1982             0.2              0
# 1981             0.3              0

# %%
CoLFactor = df[[
      'TotalFertilityRate',
      'AllItems',
      'Food',
      'Clothing&Footwear',
      'Housing&Utilities',
      'HouseholdDurables&Services',
      'HouseholdServices&Supplies',
      'HealthCare',
      'Transport',
      'PrivateTransport',
      'PublicTransport',
      'OtherTransportServices',
      'Communication',
      'Recreation&Culture',
      'Education',
      'MiscellaneousGoods&Services',
      'PersonalCare',
      'AlcoholicDrinks&Tobacco',
      'PersonalEffects',
      'AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation',
      'AllItemsLessAccommodation']]

CoLFactor = CoLFactor.dropna()
CoLFactor = CoLFactor.replace('na', 0)
CoLFactor = CoLFactor.replace(',', '', regex=True)
CoLFactor
# Out:
#        TotalFertilityRate  AllItems     Food  Clothing&Footwear  \
# Years
# 2022                 1.05   108.370  108.813             93.416
# 2021                 1.12   102.119  103.326             90.845
# 2020                 1.10    99.818  101.862             96.160
# 2019                 1.14   100.000  100.000            100.000
# 2018                 1.14    99.438   98.498            100.777
# ...                   ...       ...      ...                ...
# 1965                 4.66    25.513   22.926             54.390
# 1964                 4.97    25.448   23.034             53.723
# 1963                 5.16    25.033   22.468             53.415
# 1962                 5.21    24.513   21.674             53.590
# 1961                 5.41    24.401   21.522             53.847
#
#        Housing&Utilities  HouseholdDurables&Services  \
# Years
# 2022             106.406                     103.842
# 2021             101.100                     101.766
# 2020              99.714                     100.285
# 2019             100.000                     100.000
# 2018             101.003                      99.227
# ...                  ...                         ...
# 1965              27.908                      32.343
# 1964              27.401                      31.574
# 1963              26.907                      31.498
# 1962              26.849                      32.154
# 1961              26.688                      32.110
#
#       HouseholdServices&Supplies  HealthCare  Transport PrivateTransport  ...  \
# Years                                                                     ...
# 2022                     103.286     101.746    125.793          130.958  ...
# 2021                     101.894      99.579    108.055          109.898  ...
# 2020                     100.507      98.463     99.270           98.641  ...
# 2019                         100     100.000    100.000              100  ...
# 2018                      98.555      98.905     99.235            99.68  ...
# ...                          ...         ...        ...              ...  ...
# 1965                           0      18.604     20.608                0  ...
# 1964                           0      18.604     20.608                0  ...
# 1963                           0      18.604     20.539                0  ...
# 1962                           0      18.612     20.522                0  ...
# 1961                           0      18.604     20.537                0  ...
#
#       OtherTransportServices Communication  Recreation&Culture  Education  \
# Years
# 2022                   113.6        98.896             103.484    102.747
# 2021                 100.839       100.095              99.228    100.633
# 2020                  96.935       100.681              98.210     99.370
# 2019                     100       100.000             100.000    100.000
# 2018                  99.261       100.924              98.948     97.661
# ...                      ...           ...                 ...        ...
# 1965                       0       133.733              49.124     15.218
# 1964                       0        96.585              49.124     15.578
# 1963                       0        89.155              49.077     15.412
# 1962                       0        89.155              49.124     14.930
# 1961                       0        89.155              49.124     14.874
#
#        MiscellaneousGoods&Services  PersonalCare AlcoholicDrinks&Tobacco  \
# Years
# 2022                        98.739        100.14                  100.16
# 2021                        98.282        98.496                  98.947
# 2020                        98.823        99.947                  99.024
# 2019                       100.000           100                     100
# 2018                        99.635        99.298                   99.57
# ...                            ...           ...                     ...
# 1965                        18.910             0                       0
# 1964                        18.586             0                       0
# 1963                        18.823             0                       0
# 1962                        18.826             0                       0
# 1961                        18.833             0                       0
#
#       PersonalEffects  \
# Years
# 2022            97.16
# 2021           96.432
# 2020            94.88
# 2019              100
# 2018           100.58
# ...               ...
# 1965                0
# 1964                0
# 1963                0
# 1962                0
# 1961                0
#
#       AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation  \
# Years
# 2022                                             108.705
# 2021                                             102.128
# 2020                                              99.683
# 2019                                                 100
# 2018                                              99.098
# ...                                                  ...
# 1965                                                   0
# 1964                                                   0
# 1963                                                   0
# 1962                                                   0
# 1961                                                   0
#
#       AllItemsLessAccommodation
# Years
# 2022                    108.992
# 2021                    102.197
# 2020                     99.657
# 2019                        100
# 2018                     99.067
# ...                         ...
# 1965                          0
# 1964                          0
# 1963                          0
# 1962                          0
# 1961                          0
#
# [62 rows x 21 columns]

# %%
FerFactor = df[[
      'TotalFertilityRate',
      'F.15to19Years',
      'F.20to24Years',
      'F.25to29Years',
      'F.30to34Years',
      'F.35to39Years',
      'F.40to44Years',
      'F.45to49Years']]


FerFactor = FerFactor.dropna()
FerFactor = FerFactor.replace('na', 0)
FerFactor = FerFactor.replace(',', '', regex=True)
FerFactor
# Out:
#        TotalFertilityRate  F.15to19Years  F.20to24Years  F.25to29Years  \
# Years
# 2022                 1.05            2.1           11.3           49.1
# 2021                 1.12            2.2           11.7           53.4
# 2020                 1.10            2.3           12.7           54.6
# 2019                 1.14            2.5           12.7           59.4
# 2018                 1.14            2.5           14.4           60.6
# ...                   ...            ...            ...            ...
# 1965                 4.66           35.9          227.1          259.5
# 1964                 4.97           38.3          240.0          277.6
# 1963                 5.16           45.7          249.0          287.2
# 1962                 5.21           52.0          245.5          291.7
# 1961                 5.41           63.4          241.1          304.9
#
#        F.30to34Years  F.35to39Years  F.40to44Years F.45to49Years
# Years
# 2022            87.1           49.5            9.8           0.4
# 2021            92.9           53.6           10.2           0.3
# 2020            90.8           49.0            9.5           0.5
# 2019            92.4           50.1            9.9           0.4
# 2018            92.9           48.4            8.8           0.5
# ...              ...            ...            ...           ...
# 1965           216.2          138.1           54.9             0
# 1964           226.7          147.7           62.8             0
# 1963           228.7          156.1           64.9             0
# 1962           231.5          156.2           65.1             0
# 1961           238.4          168.9           64.8             0
#
# [62 rows x 8 columns]

# %%
#Change all the columns to float64
CoLFactor = CoLFactor.astype(float).round(2)

#Change all the columns to float64
EduFactor = EduFactor.astype(float).round(2)

#Change all the columns to float64
MarFactor = MarFactor.astype(float).round(2)

#Change all the columns to float64
FerFactor = FerFactor.astype(float).round(2)

# %%
#Change all the 0s to mean value
EduFactor = EduFactor.replace(0, EduFactor.mean())
CoLFactor = CoLFactor.replace(0, CoLFactor.mean())
MarFactor = MarFactor.replace(0, CoLFactor.mean())
FerFactor = FerFactor.replace(0, CoLFactor.mean())

# %%
#Saving the data as picklefiles
EduFactor.to_pickle('EduFactor.pickle')
CoLFactor.to_pickle('CoLFactor.pickle')
MarFactor.to_pickle('MarFactor.pickle')
FerFactor.to_pickle('FerFactor.pickle')

# %% [markdown]
# # Multi-Variate Linear Regression

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Import the required function from sklearn
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Using Education to predict Total Fertility Rate

# %%
eduData_pickle = pd.read_pickle('EduFactor.pickle')
eduData_pickle
# Out:
#        TotalFertilityRate  BelowSecondary  Secondary  \
# Years
# 2022                 1.05        369800.0   271500.0
# 2021                 1.12        362700.0   281300.0
# 2020                 1.10        433400.0   269300.0
# 2019                 1.14        426500.0   282800.0
# 2018                 1.14        441500.0   285600.0
# 2017                 1.16        464700.0   271900.0
# 2016                 1.20        469900.0   281800.0
# 2015                 1.24        454900.0   291800.0
# 2014                 1.25        468700.0   285500.0
# 2013                 1.19        472700.0   280600.0
# 2012                 1.29        480100.0   281900.0
# 2011                 1.20        491000.0   285100.0
# 2010                 1.15        499600.0   268300.0
# 2009                 1.22        518900.0   304800.0
# 2008                 1.28        497600.0   307700.0
# 2007                 1.29        538700.0   297800.0
# 2006                 1.28        543900.0   291600.0
# 2005                 1.26        524400.0   256800.0
# 2004                 1.26        551400.0   270900.0
# 2003                 1.27        554300.0   281900.0
# 2002                 1.37        547300.0   287500.0
# 2001                 1.41        545900.0   276300.0
# 2000                 1.60        517300.0   255900.0
# 1999                 1.47        552400.0   269800.0
# 1998                 1.48        554700.0   264400.0
# 1997                 1.61        563700.0   248300.0
# 1996                 1.66        544400.0   250700.0
# 1995                 1.67        531000.0   246200.0
# 1994                 1.71        549700.0   230800.0
# 1993                 1.74        547300.0   217400.0
# 1992                 1.72        543400.0   215400.0
# 1991                 1.73        540100.0   205300.0
# 1990                 1.83        535200.0   191800.0
#
#        PostSecondary(NontoTertiary)  Diploma&ProfessionalQualification  \
# Years
# 2022                       147700.0                           265100.0
# 2021                       130000.0                           239000.0
# 2020                       138800.0                           226700.0
# 2019                       122400.0                           225700.0
# 2018                       117600.0                           215400.0
# 2017                       118200.0                           207300.0
# 2016                       110600.0                           199700.0
# 2015                       113200.0                           200200.0
# 2014                       107800.0                           198200.0
# 2013                       104700.0                           183400.0
# 2012                       107300.0                           177300.0
# 2011                       102900.0                           166100.0
# 2010                       112600.0                           165100.0
# 2009                        72800.0                           149100.0
# 2008                        71600.0                           140500.0
# 2007                        75300.0                           131500.0
# 2006                        74000.0                           122400.0
# 2005                       102800.0                           126400.0
# 2004                        73400.0                           106900.0
# 2003                        72800.0                            99300.0
# 2002                        70600.0                            86100.0
# 2001                        67700.0                            84500.0
# 2000                        91800.0                            91200.0
# 1999                        72100.0                            69600.0
# 1998                        71200.0                            61400.0
# 1997                        68000.0                            49500.0
# 1996                        65100.0                            48000.0
# 1995                        72700.0                            40200.0
# 1994                        59300.0                            33200.0
# 2002                        70600.0                            86100.0
# 2001                        67700.0                            84500.0
# 2000                        91800.0                            91200.0
# 1999                        72100.0                            69600.0
# 1998                        71200.0                            61400.0
# 1997                        68000.0                            49500.0
# 1996                        65100.0                            48000.0
# 1995                        72700.0                            40200.0
# 1994                        59300.0                            33200.0
# 1993                        55700.0                            28000.0
# 1992                        53200.0                            26900.0
# 1991                        50100.0                            21000.0
# 1990                        36700.0                            18900.0
#
#        University
# Years
# 2022     552400.0
# 2021     534200.0
# 2020     496600.0
# 2019     470500.0
# 2018     440400.0
# 2017     420500.0
# 2016     398700.0
# 2015     374800.0
# 2014     362400.0
# 2013     350000.0
# 2012     320700.0
# 2011     307300.0
# 2010     288100.0
# 2009     266400.0
# 2008     246300.0
# 2007     226300.0
# 2006     212700.0
# 2005     180500.0
# 2004     172800.0
# 2003     158600.0
# 2002     140000.0
# 2001     121200.0
# 2000     105100.0
# 1999      94100.0
# 1998      87500.0
# 1997      75500.0
# 1996      69100.0
# 1995      54300.0
# 1994      49600.0
# 1993      44500.0
# 1992      37100.0
# 1991      31400.0
# 1990      28900.0

# %%
# Extract Response and Predictors
edu_y = pd.DataFrame(eduData['TotalFertilityRate'])
edu_x = pd.DataFrame(eduData[['BelowSecondary','Secondary','PostSecondary(NontoTertiary)', 'Diploma&ProfessionalQualification', 'University']])

# Split the Dataset into random Train and Test
edu_x_train, edu_x_test, edu_y_train, edu_y_test = train_test_split(edu_x, edu_y, test_size = 0.2)

# Check the sample sizes
print("Train Set :", edu_x_train.shape, edu_y_train.shape)
print("Test Set  :", edu_x_test.shape, edu_y_test.shape)

# Create a Linear Regression object
linreg = LinearRegression()

# Train the Linear Regression model
linreg.fit(edu_x_train, edu_y_train)
# Out:
# Train Set : (26, 5) (26, 1)
# Test Set  : (7, 5) (7, 1)
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [3.88150583]
# Coefficients 	: a =  [[-2.96612526e-06 -1.74293122e-06 -1.92800422e-06 -5.53035049e-07
#   -1.35676020e-06]]

# %%
# Predict TotalFertilityRate values corresponding to Predictors
edu_y_train_pred = linreg.predict(edu_x_train)
edu_y_test_pred = linreg.predict(edu_x_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(edu_y_train, edu_y_train_pred, color = "blue")
axes[0].plot(edu_y_train, edu_y_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(edu_y_test, edu_y_test_pred, color = "green")
axes[1].plot(edu_y_test, edu_y_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
print("Explained Variance (R^2) on Train Set \t:", linreg.score(edu_x_train, edu_y_train))
print("Mean Squared Error (MSE) on Train Set \t:", mean_squared_error(edu_y_train, edu_y_train_pred))
print("Explained Variance (R^2) on Test Set \t:", linreg.score(edu_x_test, edu_y_test))
print("Mean Squared Error (MSE) on Test Set \t:", mean_squared_error(edu_y_test, edu_y_test_pred))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.9379321432795558
# Mean Squared Error (MSE) on Train Set 	: 0.002797681096767193
# Explained Variance (R^2) on Test Set 	: 0.9515178344261085
# Mean Squared Error (MSE) on Test Set 	: 0.003411561365281185

# %% [markdown]
# ## Using Cost of Living to predict Total Fertility Rate

# %%
CoLData_pickle = pd.read_pickle('CoLFactor.pickle')
CoLData_pickle
# Out:
#        TotalFertilityRate  AllItems    Food  Clothing&Footwear  \
# Years
# 2022                 1.05    108.37  108.81              93.42
# 2021                 1.12    102.12  103.33              90.84
# 2020                 1.10     99.82  101.86              96.16
# 2019                 1.14    100.00  100.00             100.00
# 2018                 1.14     99.44   98.50             100.78
# ...                   ...       ...     ...                ...
# 1965                 4.66     25.51   22.93              54.39
# 1964                 4.97     25.45   23.03              53.72
# 1963                 5.16     25.03   22.47              53.42
# 1962                 5.21     24.51   21.67              53.59
# 1961                 5.41     24.40   21.52              53.85
#
#        Housing&Utilities  HouseholdDurables&Services  \
# Years
# 2022              106.41                      103.84
# 2021              101.10                      101.77
# 2020               99.71                      100.28
# 2019              100.00                      100.00
# 2018              101.00                       99.23
# ...                  ...                         ...
# 1965               27.91                       32.34
# 1964               27.40                       31.57
# 1963               26.91                       31.50
# 1962               26.85                       32.15
# 1961               26.69                       32.11
#
#        HouseholdServices&Supplies  HealthCare  Transport  PrivateTransport  \
# Years
# 2022                   103.290000      101.75     125.79        130.960000
# 2021                   101.890000       99.58     108.06        109.900000
# 2020                   100.510000       98.46      99.27         98.640000
# 2019                   100.000000      100.00     100.00        100.000000
# 2018                    98.560000       98.90      99.24         99.680000
# ...                           ...         ...        ...               ...
# 1965                    31.757097       18.60      20.61         33.176452
# 1964                    31.757097       18.60      20.61         33.176452
# 1963                    31.757097       18.60      20.54         33.176452
# 1962                    31.757097       18.61      20.52         33.176452
# 1961                    31.757097       18.60      20.54         33.176452
#
#        ...  OtherTransportServices  Communication  Recreation&Culture  \
# Years  ...
# 2022   ...              113.600000          98.90              103.48
# 2021   ...              100.840000         100.10               99.23
# 2020   ...               96.940000         100.68               98.21
# 2019   ...              100.000000         100.00              100.00
# 2018   ...               99.260000         100.92               98.95
# ...    ...                     ...            ...                 ...
# 1965   ...               35.565806         133.73               49.12
# 1964   ...               35.565806          96.58               49.12
# 1963   ...               35.565806          89.16               49.08
# 1962   ...               35.565806          89.16               49.12
# 1961   ...               35.565806          89.16               49.12
#
#        Education  MiscellaneousGoods&Services  PersonalCare  \
# Years
# 2022      102.75                        98.74    100.140000
# 2021      100.63                        98.28     98.500000
# 2020       99.37                        98.82     99.950000
# 2019      100.00                       100.00    100.000000
# 2018       97.66                        99.64     99.300000
# ...          ...                          ...           ...
# 1965       15.22                        18.91     36.112581
# 1964       15.58                        18.59     36.112581
# 1963       15.41                        18.82     36.112581
# 1962       14.93                        18.83     36.112581
# 1961       14.87                        18.83     36.112581
#
#        AlcoholicDrinks&Tobacco  PersonalEffects  \
# Years
# 2022                   100.160        97.160000
# 2021                    98.950        96.430000
# 2020                    99.020        94.880000
# 2019                   100.000       100.000000
# 2018                    99.570       100.580000
# ...                        ...              ...
# 1965                    31.005        36.054032
# 1964                    31.005        36.054032
# 1963                    31.005        36.054032
# 1962                    31.005        36.054032
# 1961                    31.005        36.054032
#
#        AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation  \
# Years
# 2022                                          108.700000
# 2021                                          102.130000
# 2020                                           99.680000
# 2019                                          100.000000
# 2018                                           99.100000
# ...                                                  ...
# 1965                                           23.002742
# 1964                                           23.002742
# 1963                                           23.002742
# 1962                                           23.002742
# 1961                                           23.002742
#
#        AllItemsLessAccommodation
# Years
# 2022                  108.990000
# 2021                  102.200000
# 2020                   99.660000
# 2019                  100.000000
# 2018                   99.070000
# ...                          ...
# 1965                   32.769516
# 1964                   32.769516
# 1963                   32.769516
# 1962                   32.769516
# 1961                   32.769516
#
# [62 rows x 21 columns]

# %%
#Some Data Cleaning to prepare the data.
CoLData = pd.DataFrame(CoLData_pickle)
CoLData
# Out:
#        TotalFertilityRate  AllItems    Food  Clothing&Footwear  \
# Years
# 2022                 1.05    108.37  108.81              93.42
# 2021                 1.12    102.12  103.33              90.84
# 2020                 1.10     99.82  101.86              96.16
# 2019                 1.14    100.00  100.00             100.00
# 2018                 1.14     99.44   98.50             100.78
# ...                   ...       ...     ...                ...
# 1965                 4.66     25.51   22.93              54.39
# 1964                 4.97     25.45   23.03              53.72
# 1963                 5.16     25.03   22.47              53.42
# 1962                 5.21     24.51   21.67              53.59
# 1961                 5.41     24.40   21.52              53.85
#
#        Housing&Utilities  HouseholdDurables&Services  \
# Years
# 2022              106.41                      103.84
# 2021              101.10                      101.77
# 2020               99.71                      100.28
# 2019              100.00                      100.00
# 2018              101.00                       99.23
# ...                  ...                         ...
# 1965               27.91                       32.34
# 1964               27.40                       31.57
# 1963               26.91                       31.50
# 1962               26.85                       32.15
# 1961               26.69                       32.11
#
#        HouseholdServices&Supplies  HealthCare  Transport  PrivateTransport  \
# Years
# 2022                   103.290000      101.75     125.79        130.960000
# 2021                   101.890000       99.58     108.06        109.900000
# 2020                   100.510000       98.46      99.27         98.640000
# 2019                   100.000000      100.00     100.00        100.000000
# 2018                    98.560000       98.90      99.24         99.680000
# ...                           ...         ...        ...               ...
# 1965                    31.757097       18.60      20.61         33.176452
# 1964                    31.757097       18.60      20.61         33.176452
# 1963                    31.757097       18.60      20.54         33.176452
# 1962                    31.757097       18.61      20.52         33.176452
# 1961                    31.757097       18.60      20.54         33.176452
#
#        ...  OtherTransportServices  Communication  Recreation&Culture  \
# Years  ...
# 2022   ...              113.600000          98.90              103.48
# 2021   ...              100.840000         100.10               99.23
# 2020   ...               96.940000         100.68               98.21
# 2019   ...              100.000000         100.00              100.00
# 2018   ...               99.260000         100.92               98.95
# ...    ...                     ...            ...                 ...
# 1965   ...               35.565806         133.73               49.12
# 1964   ...               35.565806          96.58               49.12
# 1963   ...               35.565806          89.16               49.08
# 1962   ...               35.565806          89.16               49.12
# 1961   ...               35.565806          89.16               49.12
#
#        Education  MiscellaneousGoods&Services  PersonalCare  \
# Years
# 2022      102.75                        98.74    100.140000
# 2021      100.63                        98.28     98.500000
# 2020       99.37                        98.82     99.950000
# 2019      100.00                       100.00    100.000000
# 2018       97.66                        99.64     99.300000
# ...          ...                          ...           ...
# 1965       15.22                        18.91     36.112581
# 1964       15.58                        18.59     36.112581
# 1963       15.41                        18.82     36.112581
# 1962       14.93                        18.83     36.112581
# 1961       14.87                        18.83     36.112581
#
#        AlcoholicDrinks&Tobacco  PersonalEffects  \
# Years
# 2022                   100.160        97.160000
# 2021                    98.950        96.430000
# 2020                    99.020        94.880000
# 2019                   100.000       100.000000
# 2018                    99.570       100.580000
# ...                        ...              ...
# 1965                    31.005        36.054032
# 1964                    31.005        36.054032
# 1963                    31.005        36.054032
# 1962                    31.005        36.054032
# 1961                    31.005        36.054032
#
#        AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation  \
# Years
# 2022                                          108.700000
# 2021                                          102.130000
# 2020                                           99.680000
# 2019                                          100.000000
# 2018                                           99.100000
# ...                                                  ...
# 1965                                           23.002742
# 1964                                           23.002742
# 1963                                           23.002742
# 1962                                           23.002742
# 1961                                           23.002742
#
#        AllItemsLessAccommodation
# Years
# 2022                  108.990000
# 2021                  102.200000
# 2020                   99.660000
# 2019                  100.000000
# 2018                   99.070000
# ...                          ...
# 1965                   32.769516
# 1964                   32.769516
# 1963                   32.769516
# 1962                   32.769516
# 1961                   32.769516
#
# [62 rows x 21 columns]

# %%
# Extract Response and Predictors
CoL_y = pd.DataFrame(CoLData['TotalFertilityRate'])
CoL_x = pd.DataFrame(CoLData[['AllItems','Food','Clothing&Footwear', 'Housing&Utilities', 'HouseholdDurables&Services', 'HouseholdServices&Supplies', 'HealthCare', 'Transport', 'PrivateTransport', 'PublicTransport', 'OtherTransportServices', 'Communication', 'Recreation&Culture', 'Education', 'MiscellaneousGoods&Services', 'PersonalCare', 'AlcoholicDrinks&Tobacco', 'PersonalEffects', 'AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation', 'AllItemsLessAccommodation']])

# Split the Dataset into random Train and Test
CoL_x_train, CoL_x_test, CoL_y_train, CoL_y_test = train_test_split(CoL_x, CoL_y, test_size = 0.2)

# Check the sample sizes
print("Train Set :", CoL_x_train.shape, CoL_y_train.shape)
print("Test Set  :", CoL_x_test.shape, CoL_y_test.shape)

# Create a Linear Regression object
linreg = LinearRegression()

# Train the Linear Regression model
linreg.fit(CoL_x_train, CoL_y_train)
# Out:
# Train Set : (49, 20) (49, 1)
# Test Set  : (13, 20) (13, 1)
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [9.55542453]
# Coefficients 	: a =  [[ 0.12248013 -0.01837402 -0.01163387 -0.01279017 -0.12309436  0.10031891
#   -0.09170033  0.05423896 -0.02752733 -0.02466085 -0.00062604 -0.02316092
#    0.01784304  0.0399506  -0.03648342 -0.01370898  0.03304803  0.04352851
#    0.00962698 -0.12111068]]

# %%
# Predict TotalFertilityRate values corresponding to Predictors
CoL_y_train_pred = linreg.predict(CoL_x_train)
CoL_y_test_pred = linreg.predict(CoL_x_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(CoL_y_train, CoL_y_train_pred, color = "blue")
axes[0].plot(CoL_y_train, CoL_y_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(CoL_y_test, CoL_y_test_pred, color = "green")
axes[1].plot(CoL_y_test, CoL_y_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
print("Explained Variance (R^2) on Train Set \t:", linreg.score(CoL_x_train, CoL_y_train))
print("Mean Squared Error (MSE) on Train Set \t:", mean_squared_error(CoL_y_train, CoL_y_train_pred))
print("Explained Variance (R^2) on Test Set \t:", linreg.score(CoL_x_test, CoL_y_test))
print("Mean Squared Error (MSE) on Test Set \t:", mean_squared_error(CoL_y_test, CoL_y_test_pred))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.9801728341690416
# Mean Squared Error (MSE) on Train Set 	: 0.027981257478339516
# Explained Variance (R^2) on Test Set 	: 0.9495436628637696
# Mean Squared Error (MSE) on Test Set 	: 0.046065978977320995

# %% [markdown]
# ## Using Marriage Rate to predict Total Fertility Rate

# %%
marData_pickle = pd.read_pickle('MarFactor.pickle')
marData_pickle
# Out:
#        TotalFertilityRate  FemaleGeneralMarriageRate  M.15to19Years  \
# Years
# 2022                 1.05                       44.2            1.1
# 2021                 1.12                       34.9            1.2
# 2020                 1.10                       37.9            1.2
# 2019                 1.14                       40.8            1.2
# 2018                 1.14                       42.8            1.5
# 2017                 1.16                       41.6            1.7
# 2016                 1.20                       41.1            1.7
# 2015                 1.24                       40.8            1.7
# 2014                 1.25                       36.9            2.2
# 2013                 1.19                       39.4            2.3
# 2012                 1.29                       39.2            2.4
# 2011                 1.20                       35.3            2.8
# 2010                 1.15                       38.9            2.6
# 2009                 1.22                       39.6            3.1
# 2008                 1.28                       40.1            3.8
# 2007                 1.29                       40.0            3.9
# 2006                 1.28                       39.0            4.6
# 2005                 1.26                       41.2            5.0
# 2004                 1.26                       43.7            5.3
# 2003                 1.27                       45.8            6.3
# 2002                 1.37                       44.1            6.9
# 2001                 1.41                       46.8            7.4
# 2000                 1.60                       54.8            7.2
# 1999                 1.47                       47.9            7.6
# 1998                 1.48                       58.4            6.6
# 1997                 1.61                       52.6            7.0
# 1996                 1.66                       54.9            7.5
# 1995                 1.67                       56.1            7.9
# 1994                 1.71                       57.4            8.8
# 1993                 1.74                       59.0           10.1
# 1992                 1.72                       61.5           10.8
# 1991                 1.73                       59.2           11.0
# 1990                 1.83                       60.1           10.7
# 1989                 1.75                       65.3           10.8
# 1988                 1.96                       62.3           11.9
# 1987                 1.62                       52.6           12.4
# 1986                 1.43                       62.5           15.2
# 1985                 1.61                       66.3           15.6
# 1984                 1.62                       56.4           15.7
# 1983                 1.61                       63.9           17.2
# 1982                 1.74                       68.7           17.8
# 1981                 1.78                       67.3           18.4
# 1995            16.7            9.9            3.2            1.3
# 1994            17.9           10.9            3.3            1.5
# 1993            17.5            9.2            3.7            1.2
# 1992            15.6            8.8            3.8            1.3
# 1991            14.7            6.7            3.6            0.8
# 1990            20.3            8.6            3.4            0.9
# 1989            20.7            7.9            3.6            1.2
# 1988            19.3            9.2            2.8            0.9
# 1987            17.3            9.3            3.7            0.9
# 1986            18.5            7.2            3.3            1.1
# 1985            16.7            8.4            2.8            1.2
# 1984            19.1            9.6            3.3            1.5
# 1983            23.7           11.3            3.0            1.9
# 1982            26.2           14.4            3.8            3.2
# 1981            22.0            9.2            2.6            2.1
#
#        M.60to64Years  M.65Years&Over
# Years
# 2022             1.7             0.3
# 2021             1.3             0.2
# 2020             1.5             0.3
# 2019             1.5             0.2
# 2018             1.3             0.2
# 2017             1.4             0.2
# 2016             1.3             0.2
# 2015             1.0             0.1
# 2014             0.9             0.2
# 2013             1.3             0.2
# 2012             1.3             0.1
# 2011             0.9             0.2
# 2010             1.0             0.1
# 2009             1.0             0.2
# 2008             0.7             0.2
# 2007             0.8             0.2
# 2006             1.1             0.1
# 2005             0.6             0.2
# 2004             0.5             0.0
# 2003             0.6             0.1
# 2002             1.0             0.1
# 2001             0.8             0.2
# 2000             1.1             0.1
# 1999             0.7             0.1
# 1998             0.9             0.2
# 1997             0.7             0.1
# 1996             0.6             0.1
# 1995             0.4             0.2
# 1994             0.6             0.1
# 1993             0.4             0.1
# 1992             0.6             0.1
# 1991             0.3             0.1
# 1990             0.7             0.1
# 1989             0.6             0.2
# 1988             0.8             0.1
# 1987             0.4             0.1
# 1986             0.2             0.1
# 1985             0.6             0.1
# 1984             0.2             0.0
# 1983             0.3             0.0
# 1982             0.2             0.0
# 1981             0.3             0.0

# %%
#Some Data Cleaning to prepare the data.
marData = pd.DataFrame(marData_pickle)
marData
# Out:
#        TotalFertilityRate  FemaleGeneralMarriageRate  M.15to19Years  \
# Years
# 2022                 1.05                       44.2            1.1
# 2021                 1.12                       34.9            1.2
# 2020                 1.10                       37.9            1.2
# 2019                 1.14                       40.8            1.2
# 2018                 1.14                       42.8            1.5
# 2017                 1.16                       41.6            1.7
# 2016                 1.20                       41.1            1.7
# 2015                 1.24                       40.8            1.7
# 2014                 1.25                       36.9            2.2
# 2013                 1.19                       39.4            2.3
# 2012                 1.29                       39.2            2.4
# 2011                 1.20                       35.3            2.8
# 2010                 1.15                       38.9            2.6
# 2009                 1.22                       39.6            3.1
# 2008                 1.28                       40.1            3.8
# 2007                 1.29                       40.0            3.9
# 2006                 1.28                       39.0            4.6
# 2005                 1.26                       41.2            5.0
# 2004                 1.26                       43.7            5.3
# 2003                 1.27                       45.8            6.3
# 2002                 1.37                       44.1            6.9
# 2001                 1.41                       46.8            7.4
# 2000                 1.60                       54.8            7.2
# 1999                 1.47                       47.9            7.6
# 1998                 1.48                       58.4            6.6
# 1997                 1.61                       52.6            7.0
# 1996                 1.66                       54.9            7.5
# 1995                 1.67                       56.1            7.9
# 1994                 1.71                       57.4            8.8
# 2007            17.5            8.3            4.3            2.2
# 2006            15.0            9.1            4.3            2.1
# 2005            16.4            8.9            4.1            2.2
# 2004            15.9            8.9            3.4            2.1
# 2003            14.1            7.9            3.4            2.2
# 2002            14.8            7.4            3.4            1.8
# 2001            17.2            8.2            4.2            1.6
# 2000            18.0            9.7            4.6            1.7
# 1999            16.8            8.5            5.0            1.3
# 1998            19.6            9.9            5.3            1.6
# 1997            19.0            8.2            3.6            1.3
# 1996            16.9            8.3            3.3            2.6
# 1995            16.7            9.9            3.2            1.3
# 1994            17.9           10.9            3.3            1.5
# 1993            17.5            9.2            3.7            1.2
# 1992            15.6            8.8            3.8            1.3
# 1991            14.7            6.7            3.6            0.8
# 1990            20.3            8.6            3.4            0.9
# 1989            20.7            7.9            3.6            1.2
# 1988            19.3            9.2            2.8            0.9
# 1987            17.3            9.3            3.7            0.9
# 1986            18.5            7.2            3.3            1.1
# 1985            16.7            8.4            2.8            1.2
# 1984            19.1            9.6            3.3            1.5
# 1983            23.7           11.3            3.0            1.9
# 1982            26.2           14.4            3.8            3.2
# 1981            22.0            9.2            2.6            2.1
#
#        M.60to64Years  M.65Years&Over
# Years
# 2022             1.7             0.3
# 2021             1.3             0.2
# 2020             1.5             0.3
# 2019             1.5             0.2
# 2018             1.3             0.2
# 2017             1.4             0.2
# 2016             1.3             0.2
# 2015             1.0             0.1
# 2014             0.9             0.2
# 2013             1.3             0.2
# 2012             1.3             0.1
# 2011             0.9             0.2
# 2010             1.0             0.1
# 2009             1.0             0.2
# 2008             0.7             0.2
# 2007             0.8             0.2
# 2006             1.1             0.1
# 2005             0.6             0.2
# 2004             0.5             0.0
# 2003             0.6             0.1
# 2002             1.0             0.1
# 2001             0.8             0.2
# 2000             1.1             0.1
# 1999             0.7             0.1
# 1998             0.9             0.2
# 1997             0.7             0.1
# 1996             0.6             0.1
# 1995             0.4             0.2
# 1994             0.6             0.1
# 1993             0.4             0.1
# 1992             0.6             0.1
# 1991             0.3             0.1
# 1990             0.7             0.1
# 1989             0.6             0.2
# 1988             0.8             0.1
# 1987             0.4             0.1
# 1986             0.2             0.1
# 1985             0.6             0.1
# 1984             0.2             0.0
# 1983             0.3             0.0
# 1982             0.2             0.0
# 1981             0.3             0.0

# %%
# Extract Response and Predictors
mar_y = pd.DataFrame(marData['TotalFertilityRate'])
mar_x = pd.DataFrame(marData[['FemaleGeneralMarriageRate','M.15to19Years','M.20to24Years', 'M.25to29Years', 'M.30to34Years', 'M.35to39Years', 'M.40to44Years', 'M.45to49Years', 'M.50to54Years', 'M.55to59Years', 'M.60to64Years', 'M.65Years&Over']])

# Split the Dataset into random Train and Test
mar_x_train, mar_x_test, mar_y_train, mar_y_test = train_test_split(mar_x, mar_y, test_size = 0.2)

# Check the sample sizes
print("Train Set :", mar_x_train.shape, mar_y_train.shape)
print("Test Set  :", mar_x_test.shape, mar_y_test.shape)

# Create a Linear Regression object
linreg = LinearRegression()

# Train the Linear Regression model
linreg.fit(mar_x_train, mar_y_train)
# Out:
# Train Set : (33, 12) (33, 1)
# Test Set  : (9, 12) (9, 1)
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [1.21189967]
# Coefficients 	: a =  [[-2.42154235e-02 -3.06429751e-02  1.87328766e-02 -4.38050278e-05
#    5.56054875e-03  9.96333289e-03 -4.36365191e-03  2.88269606e-02
#   -1.84268463e-02 -1.65620110e-01 -1.14875027e-02 -2.22528619e-01]]

# %%
# Predict TotalFertilityRate values corresponding to Predictors
mar_y_train_pred = linreg.predict(mar_x_train)
mar_y_test_pred = linreg.predict(mar_x_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(mar_y_train, mar_y_train_pred, color = "blue")
axes[0].plot(mar_y_train, mar_y_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(mar_y_test, mar_y_test_pred, color = "green")
axes[1].plot(mar_y_test, mar_y_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
print("Explained Variance (R^2) on Train Set \t:", linreg.score(mar_x_train, mar_y_train))
print("Mean Squared Error (MSE) on Train Set \t:", mean_squared_error(mar_y_train, mar_y_train_pred))
print("Explained Variance (R^2) on Test Set \t:", linreg.score(mar_x_test, mar_y_test))
print("Mean Squared Error (MSE) on Test Set \t:", mean_squared_error(mar_y_test, mar_y_test_pred))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.9178503752140561
# Mean Squared Error (MSE) on Train Set 	: 0.004521397668315078
# Explained Variance (R^2) on Test Set 	: 0.7396598858773833
# Mean Squared Error (MSE) on Test Set 	: 0.020202392855915057

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Education has high Explained Variance (R^2) on both the Train and Test sets, and low Mean Squared Error (MSE) on both sets. It indicates that the model is well-fitted and can accurately predict the target variable for new data.
#
# Cost of Living has the highest Explained Variance on the Train set, but the highest Mean Squared Error on the Test set. It may indicate that the model is overfitted on the Train set and does not generalize well on new data.
#
# Marriage Rates has the lowest Explained Variance on both the Train and Test sets, but low Mean Squared Error on both sets. It may indicate that the model is underfitted and does not capture all the variations in the data.
#
# Overall, Education provides the most accurate prediction as it has high Explained Variance and low Mean Squared Error on both the Train and Test sets.

# %% [markdown]
# I chose to use Multi-Variate Linear Regression model as opposed to Uni-Variate Linear Regression model as when I was experimenting with the data, when I tried Uni-Variate Linear Regression model with Education dataset, I found out that 'University' level of education is the strongest predicator among all the other variables, it just means that an individuals with 'University' level of education is more likely to follow the trend line as compared to individuals with other level of education, but I realised this information does not have much value, and it is too overly specific as we are only trying to predict the general fertility rate.
#
# As such, using a Multi-Variate Linear Regression model will be useful to show that whether in general is 'Education' or 'Cost of Living' or 'Marriage Rates' a good predictor of 'Total Fertility Rate'.
