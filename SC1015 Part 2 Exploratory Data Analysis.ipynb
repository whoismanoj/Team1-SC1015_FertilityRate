# %% [markdown]
# # SC1015 DSAI Mini Project
#
# ## Part 2: Exploratory Data Analysis
#
# ---------------------------
# In this section, we explore our dataset more generally. We explore both variables related to conventionality (6 in total) as well as variables related to success (2 in total) to answer questions like are there any patterns we are noticing? What do our success variables look like? What about the conventionality variables? Are there any underlying relationships between them? Can we make any inferences for our question at this stage? This is going to help us in the later sections of our project as well as eventually answer the question we posed.

# %%
#Basic Libraries
import pandas as pd
import numpy as np

import seaborn as sb
import matplotlib.pyplot as plt 
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ### Exploring the education Data

# %%
edu_data = pd.read_pickle('EduFactor.pickle')
edu_data
# Out:
#        TotalFertilityRate(PerFemale)  BelowSecondary  Secondary  \
# Years
# 2022                            1.05        369800.0   271500.0
# 2021                            1.12        362700.0   281300.0
# 2020                            1.10        433400.0   269300.0
# 2019                            1.14        426500.0   282800.0
# 2018                            1.14        441500.0   285600.0
# 2017                            1.16        464700.0   271900.0
# 2016                            1.20        469900.0   281800.0
# 2015                            1.24        454900.0   291800.0
# 2014                            1.25        468700.0   285500.0
# 2013                            1.19        472700.0   280600.0
# 2012                            1.29        480100.0   281900.0
# 2011                            1.20        491000.0   285100.0
# 2010                            1.15        499600.0   268300.0
# 2009                            1.22        518900.0   304800.0
# 2008                            1.28        497600.0   307700.0
# 2007                            1.29        538700.0   297800.0
# 2006                            1.28        543900.0   291600.0
# 2005                            1.26        524400.0   256800.0
# 2004                            1.26        551400.0   270900.0
# 2003                            1.27        554300.0   281900.0
# 2002                            1.37        547300.0   287500.0
# 2001                            1.41        545900.0   276300.0
# 2000                            1.60        517300.0   255900.0
# 1999                            1.47        552400.0   269800.0
# 1998                            1.48        554700.0   264400.0
# 1997                            1.61        563700.0   248300.0
# 1996                            1.66        544400.0   250700.0
# 1995                            1.67        531000.0   246200.0
# 1994                            1.71        549700.0   230800.0
# 1993                            1.74        547300.0   217400.0
# 1992                            1.72        543400.0   215400.0
# 1991                            1.73        540100.0   205300.0
# 1990                            1.83        535200.0   191800.0
#
#        PostSecondary(NontoTertiary)  Diploma&ProfessionalQualification  \
# Years
# 2022                       147700.0                           265100.0
# 2021                       130000.0                           239000.0
# 2020                       138800.0                           226700.0
# 2019                       122400.0                           225700.0
# 2018                       117600.0                           215400.0
# 2017                       118200.0                           207300.0
# 2016                       110600.0                           199700.0
# 2015                       113200.0                           200200.0
# 2014                       107800.0                           198200.0
# 2013                       104700.0                           183400.0
# 2012                       107300.0                           177300.0
# 2011                       102900.0                           166100.0
# 2010                       112600.0                           165100.0
# 2009                        72800.0                           149100.0
# 2008                        71600.0                           140500.0
# 2007                        75300.0                           131500.0
# 2006                        74000.0                           122400.0
# 2005                       102800.0                           126400.0
# 2004                        73400.0                           106900.0
# 2003                        72800.0                            99300.0
# 2002                        70600.0                            86100.0
# 2001                        67700.0                            84500.0
# 2000                        91800.0                            91200.0
# 1999                        72100.0                            69600.0
# 1998                        71200.0                            61400.0
# 1997                        68000.0                            49500.0
# 1996                        65100.0                            48000.0
# 1995                        72700.0                            40200.0
# 1994                        59300.0                            33200.0
# 1993                        55700.0                            28000.0
# 1992                        53200.0                            26900.0
# 1991                        50100.0                            21000.0
# 1990                        36700.0                            18900.0
#
#        University
# Years
# 2022     552400.0
# 2021     534200.0
# 2020     496600.0
# 2019     470500.0
# 2018     440400.0
# 2017     420500.0
# 2016     398700.0
# 2015     374800.0
# 2014     362400.0
# 2013     350000.0
# 2012     320700.0
# 2011     307300.0
# 2010     288100.0
# 2009     266400.0
# 2008     246300.0
# 2007     226300.0
# 2006     212700.0
# 2005     180500.0
# 2004     172800.0
# 2003     158600.0
# 2002     140000.0
# 2001     121200.0
# 2000     105100.0
# 1999      94100.0
# 1998      87500.0
# 1997      75500.0
# 1996      69100.0
# 1995      54300.0
# 1994      49600.0
# 1993      44500.0
# 1992      37100.0
# 1991      31400.0
# 1990      28900.0

# %%
edu_data.describe().round(2)
# Out:
#        TotalFertilityRate(PerFemale)  BelowSecondary  Secondary  \
# count                          33.00           33.00      33.00
# mean                            1.37       504154.55  266930.30
# std                             0.23        53521.32   28134.79
# min                             1.05       362700.00  191800.00
# 25%                             1.20       469900.00  255900.00
# 50%                             1.28       524400.00  271900.00
# 75%                             1.60       545900.00  285100.00
# max                             1.83       563700.00  307700.00
#
#        PostSecondary(NontoTertiary)  Diploma&ProfessionalQualification  \
# count                         33.00                              33.00
# mean                       88203.03                          127387.88
# std                        27942.36                           74061.76
# min                        36700.00                           18900.00
# 25%                        70600.00                           61400.00
# 50%                        74000.00                          126400.00
# 75%                       110600.00                          198200.00
# max                       147700.00                          265100.00
#
#        University
# count       33.00
# mean    233893.94
# std     163563.91
# min      28900.00
# 25%      87500.00
# 50%     212700.00
# 75%     362400.00
# max     552400.00

# %%
# plot the data as a line plot
edu_data.plot(y=['BelowSecondary',
                 'Secondary',
                 'PostSecondary(NontoTertiary)',
                 'Diploma&ProfessionalQualification',
                 'University'])

# display the plot
plt.show()

# %%
# plot the data as a line plot
edu_data.plot(y=['TotalFertilityRate(PerFemale)'])

# display the plot
plt.show()

# %%
Fertility = pd.DataFrame(edu_data['TotalFertilityRate(PerFemale)'])
BelowSecondary = pd.DataFrame(edu_data['BelowSecondary'])
Secondary = pd.DataFrame(edu_data['Secondary'])
PostSecondary = pd.DataFrame({
    'PostSecondary(NontoTertiary)': edu_data['PostSecondary(NontoTertiary)'],
    'Diploma&ProfessionalQualification': edu_data['Diploma&ProfessionalQualification']
})
University = pd.DataFrame(edu_data['University'])

# %%
f, axes = plt.subplots(5, 3, figsize=(24, 12))

#Fertility
sb.boxplot(data = Fertility, orient = "h",ax = axes[0,0])
sb.histplot(data = Fertility,ax = axes[0,1])
sb.violinplot(data = Fertility, orient = "h",ax = axes[0,2])

#BelowSecondary
sb.boxplot(data = BelowSecondary, orient = "h",ax = axes[1,0])
sb.histplot(data = BelowSecondary,ax = axes[1,1])
sb.violinplot(data = BelowSecondary, orient = "h",ax = axes[1,2])

#Secondary
sb.boxplot(data = Secondary, orient = "h",ax = axes[2,0])
sb.histplot(data = Secondary,ax = axes[2,1])
sb.violinplot(data = Secondary, orient = "h",ax = axes[2,2])

#PostSecondary
sb.boxplot(data = PostSecondary, orient = "h",ax = axes[3,0])
sb.histplot(data = PostSecondary,ax = axes[3,1])
sb.violinplot(data = PostSecondary, orient = "h",ax = axes[3,2])

#University
sb.boxplot(data = University, orient = "h",ax = axes[4,0])
sb.histplot(data = University,ax = axes[4,1])
sb.violinplot(data = University, orient = "h",ax = axes[4,2])
# Out:
# <AxesSubplot:>

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([Fertility, University], axis = 1)
jointDF
# Out:
#        TotalFertilityRate(PerFemale)  University
# Years
# 2022                            1.05    552400.0
# 2021                            1.12    534200.0
# 2020                            1.10    496600.0
# 2019                            1.14    470500.0
# 2018                            1.14    440400.0
# 2017                            1.16    420500.0
# 2016                            1.20    398700.0
# 2015                            1.24    374800.0
# 2014                            1.25    362400.0
# 2013                            1.19    350000.0
# 2012                            1.29    320700.0
# 2011                            1.20    307300.0
# 2010                            1.15    288100.0
# 2009                            1.22    266400.0
# 2008                            1.28    246300.0
# 2007                            1.29    226300.0
# 2006                            1.28    212700.0
# 2005                            1.26    180500.0
# 2004                            1.26    172800.0
# 2003                            1.27    158600.0
# 2002                            1.37    140000.0
# 2001                            1.41    121200.0
# 2000                            1.60    105100.0
# 1999                            1.47     94100.0
# 1998                            1.48     87500.0
# 1997                            1.61     75500.0
# 1996                            1.66     69100.0
# 1995                            1.67     54300.0
# 1994                            1.71     49600.0
# 1993                            1.74     44500.0
# 1992                            1.72     37100.0
# 1991                            1.73     31400.0
# 1990                            1.83     28900.0

# %%
sb.jointplot(data = jointDF, x = "University", y = "TotalFertilityRate(PerFemale)", sizes=(10, 100))

# %%
CoL_data = pd.read_pickle('CoLFactor.pickle')
CoL_data
# Out:
#        TotalFertilityRate(PerFemale)  AllItems    Food  Clothing&Footwear  \
# Years
# 2022                            1.05    108.37  108.81              93.42
# 2021                            1.12    102.12  103.33              90.84
# 2020                            1.10     99.82  101.86              96.16
# 2019                            1.14    100.00  100.00             100.00
# 2018                            1.14     99.44   98.50             100.78
# ...                              ...       ...     ...                ...
# 1965                            4.66     25.51   22.93              54.39
# 1964                            4.97     25.45   23.03              53.72
# 1963                            5.16     25.03   22.47              53.42
# 1962                            5.21     24.51   21.67              53.59
# 1961                            5.41     24.40   21.52              53.85
#
#        Housing&Utilities  HouseholdDurables&Services  \
# Years
# 2022              106.41                      103.84
# 2021              101.10                      101.77
# 2020               99.71                      100.28
# 2019              100.00                      100.00
# 2018              101.00                       99.23
# ...                  ...                         ...
# 1965               27.91                       32.34
# 1964               27.40                       31.57
# 1963               26.91                       31.50
# 1962               26.85                       32.15
# 1961               26.69                       32.11
#
#        HouseholdServices&Supplies  HealthCare  Transport  PrivateTransport  \
# Years
# 2022                       103.29      101.75     125.79            130.96
# 2021                       101.89       99.58     108.06            109.90
# 2020                       100.51       98.46      99.27             98.64
# 2019                       100.00      100.00     100.00            100.00
# 2018                        98.56       98.90      99.24             99.68
# ...                           ...         ...        ...               ...
# 1965                        31.76       18.60      20.61             33.18
# 1964                        31.76       18.60      20.61             33.18
# 1963                        31.76       18.60      20.54             33.18
# 1962                        31.76       18.61      20.52             33.18
# 1961                        31.76       18.60      20.54             33.18
#
#        ...  OtherTransportServices  Communication  Recreation&Culture  \
# Years  ...
# 2022   ...                  113.60          98.90              103.48
# 2021   ...                  100.84         100.10               99.23
# 2020   ...                   96.94         100.68               98.21
# 2019   ...                  100.00         100.00              100.00
# 2018   ...                   99.26         100.92               98.95
# ...    ...                     ...            ...                 ...
# 1965   ...                   35.57         133.73               49.12
# 1964   ...                   35.57          96.58               49.12
# 1963   ...                   35.57          89.16               49.08
# 1962   ...                   35.57          89.16               49.12
# 1961   ...                   35.57          89.16               49.12
#
#        Education  MiscellaneousGoods&Services  PersonalCare  \
# Years
# 2022      102.75                        98.74        100.14
# 2021      100.63                        98.28         98.50
# 2020       99.37                        98.82         99.95
# 2019      100.00                       100.00        100.00
# 2018       97.66                        99.64         99.30
# ...          ...                          ...           ...
# 1965       15.22                        18.91         36.11
# 1964       15.58                        18.59         36.11
# 1963       15.41                        18.82         36.11
# 1962       14.93                        18.83         36.11
# 1961       14.87                        18.83         36.11
#
#        AlcoholicDrinks&Tobacco  PersonalEffects  \
# Years
# 2022                    100.16            97.16
# 2021                     98.95            96.43
# 2020                     99.02            94.88
# 2019                    100.00           100.00
# 2018                     99.57           100.58
# ...                        ...              ...
# 1965                     31.00            36.05
# 1964                     31.00            36.05
# 1963                     31.00            36.05
# 1962                     31.00            36.05
# 1961                     31.00            36.05
#
#        AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation  \
# Years
# 2022                                              108.70
# 2021                                              102.13
# 2020                                               99.68
# 2019                                              100.00
# 2018                                               99.10
# ...                                                  ...
# 1965                                               23.00
# 1964                                               23.00
# 1963                                               23.00
# 1962                                               23.00
# 1961                                               23.00
#
#        AllItemsLessAccommodation
# Years
# 2022                      108.99
# 2021                      102.20
# 2020                       99.66
# 2019                      100.00
# 2018                       99.07
# ...                          ...
# 1965                       32.77
# 1964                       32.77
# 1963                       32.77
# 1962                       32.77
# 1961                       32.77
#
# [62 rows x 21 columns]

# %%
CoL_data.describe().round(2)
# Out:
#        TotalFertilityRate(PerFemale)  AllItems    Food  Clothing&Footwear  \
# count                          62.00     62.00   62.00              62.00
# mean                            2.04     63.46   60.21              83.31
# std                             1.16     25.43   24.72              15.32
# min                             1.05     24.40   21.52              53.42
# 25%                             1.27     42.44   42.59              76.94
# 50%                             1.64     65.63   59.77              88.56
# 75%                             2.04     78.84   73.87              94.50
# max                             5.41    108.37  108.81             100.78
#
#        Housing&Utilities  HouseholdDurables&Services  \
# count              62.00                       62.00
# mean               64.57                       70.85
# std                27.07                       21.48
# min                26.69                       31.50
# 25%                41.66                       58.01
# 50%                64.34                       77.17
# 75%                77.77                       84.09
# max               113.52                      103.84
#
#        HouseholdServices&Supplies  HealthCare  Transport  PrivateTransport  \
# count                       62.00       62.00      62.00             62.00
# mean                        51.74       53.27      60.33             54.05
# std                         27.09       27.78      29.33             29.04
# min                         31.76       18.60      20.52             33.18
# 25%                         31.76       26.73      31.71             33.18
# 50%                         31.76       51.89      65.71             33.18
# 75%                         77.06       74.45      76.76             75.60
# max                        103.29      101.75     125.79            130.96
#
#        ...  OtherTransportServices  Communication  Recreation&Culture  \
# count  ...                   62.00          62.00               62.00
# mean   ...                   57.94         117.44               76.38
# std    ...                   29.62          15.35               18.12
# min    ...                   35.57          89.16               49.08
# 25%    ...                   35.57         103.56               56.40
# 50%    ...                   35.57         116.85               84.02
# 75%    ...                   91.33         133.73               90.53
# max    ...                  113.60         139.20              103.48
#
#        Education  MiscellaneousGoods&Services  PersonalCare  \
# count      62.00                        62.00         62.00
# mean       45.65                        59.01         58.83
# std        29.17                        29.40         29.89
# min        14.87                        18.59         36.11
# 25%        17.50                        31.49         36.11
# 50%        39.44                        59.05         36.11
# 75%        68.02                        90.35         95.20
# max       102.75                       100.00        101.10
#
#        AlcoholicDrinks&Tobacco  PersonalEffects  \
# count                    62.00            62.00
# mean                     50.50            58.73
# std                      27.41            29.81
# min                      31.00            36.05
# 25%                      31.00            36.05
# 50%                      31.00            36.05
# 75%                      83.19            95.48
# max                     100.16           101.14
#
#        AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation  \
# count                                              62.00
# mean                                               40.44
# std                                                31.30
# min                                                23.00
# 25%                                                23.00
# 50%                                                23.00
# 75%                                                23.00
# max                                               108.70
#
#        AllItemsLessAccommodation
# count                      62.00
# mean                       53.38
# std                        27.84
# min                        32.77
# 25%                        32.77
# 50%                        32.77
# 75%                        78.89
# max                       108.99
#
# [8 rows x 21 columns]

# %%
# plot the data as a line plot
CoL_data.plot(y=['AllItems',
                 'Food',
                 'Clothing&Footwear',
                 'Housing&Utilities',
                 'HouseholdDurables&Services',
                'HouseholdServices&Supplies',
                'HealthCare',
                'Transport',
                'PrivateTransport',
                'OtherTransportServices',
                'Communication',
                'Recreation&Culture',
                'Education',
                 'MiscellaneousGoods&Services',
                 'PersonalCare',
                 'AlcoholicDrinks&Tobacco',
                 'PersonalEffects',
                 'AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation',
                 'AllItemsLessAccommodation'])

# display the plot
plt.show()

# %%
Fertility = pd.DataFrame(CoL_data['TotalFertilityRate(PerFemale)'])
Food = pd.DataFrame(CoL_data['Food'])
Clothing = pd.DataFrame(CoL_data['Clothing&Footwear'])
Household = pd.DataFrame({
    'Housing&Utilities': CoL_data['Housing&Utilities'],
    'HouseholdDurables&Services': CoL_data['HouseholdDurables&Services'],
    'HouseholdServices&Supplies' : CoL_data['HouseholdServices&Supplies']
})
Healthcare = pd.DataFrame(CoL_data['HealthCare'])
Transport = pd.DataFrame(CoL_data['Transport'])
Communication = pd.DataFrame(CoL_data['Communication'])
RecreationCulture = pd.DataFrame(CoL_data['Recreation&Culture'])
Education = pd.DataFrame(CoL_data['Education'])
Education = pd.DataFrame(CoL_data['MiscellaneousGoods&Services'])
