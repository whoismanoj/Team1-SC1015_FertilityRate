# %% [markdown]
# # SC1015 DSAI Mini Project
#
# ## Part 2: Basic Visualisation
#
# ---------------------------
# Visualisation is an essential tool for data analysis, as it allows us to communicate insights and patterns that may not be apparent from raw data. In this section, we will explore and compare 4 different data sets using basic visualisation techniques (i.e Boxplot, violin plot, graph plot)

# %%
#Basic Libraries
import pandas as pd
import numpy as np

import seaborn as sb
import matplotlib.pyplot as plt 
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ### Exploring the Fertility Data (Per 1000 females)
#
# Based on the graphs presented below, it is evident that there has been a notable decrease in the birth rate per 1000 females. For instance, females aged between 25 to 29 years old had a birth rate of around 304.9 per 1000 females in 1961, whereas the corresponding birth rate in 2022 for this age group is 49.1 per 1000 females.

# %%
fer_data = pd.read_pickle('FerFactor.pickle')
fer_data
# Out:
#        TotalFertilityRate  F.15to19Years  F.20to24Years  F.25to29Years  \
# Years
# 2022                 1.05            2.1           11.3           49.1
# 2021                 1.12            2.2           11.7           53.4
# 2020                 1.10            2.3           12.7           54.6
# 2019                 1.14            2.5           12.7           59.4
# 2018                 1.14            2.5           14.4           60.6
# ...                   ...            ...            ...            ...
# 1965                 4.66           35.9          227.1          259.5
# 1964                 4.97           38.3          240.0          277.6
# 1963                 5.16           45.7          249.0          287.2
# 1962                 5.21           52.0          245.5          291.7
# 1961                 5.41           63.4          241.1          304.9
#
#        F.30to34Years  F.35to39Years  F.40to44Years  F.45to49Years
# Years
# 2022            87.1           49.5            9.8            0.4
# 2021            92.9           53.6           10.2            0.3
# 2020            90.8           49.0            9.5            0.5
# 2019            92.4           50.1            9.9            0.4
# 2018            92.9           48.4            8.8            0.5
# ...              ...            ...            ...            ...
# 1965           216.2          138.1           54.9            0.0
# 1964           226.7          147.7           62.8            0.0
# 1963           228.7          156.1           64.9            0.0
# 1962           231.5          156.2           65.1            0.0
# 1961           238.4          168.9           64.8            0.0
#
# [62 rows x 8 columns]

# %%
fer_data.describe().round(2)
# Out:
#        TotalFertilityRate  F.15to19Years  F.20to24Years  F.25to29Years  \
# count               62.00          62.00          62.00          62.00
# mean                 2.04          13.50          77.26         134.82
# std                  1.16          13.12          67.35          67.76
# min                  1.05           2.10          11.30          49.10
# 25%                  1.27           6.22          30.75          79.08
# 50%                  1.64           8.30          52.80         125.15
# 75%                  2.04          15.50          99.15         152.75
# max                  5.41          63.40         249.00         304.90
#
#        F.30to34Years  F.35to39Years  F.40to44Years  F.45to49Years
# count          62.00          62.00          62.00          62.00
# mean          112.86          54.43          14.65           0.18
# std            40.80          34.09          16.94           0.15
# min            74.40          26.70           3.90           0.00
# 25%            90.02          37.15           6.40           0.00
# 50%            96.15          42.60           7.30           0.20
# 75%           109.10          49.85           9.98           0.30
# max           238.40         168.90          65.10           0.50

# %%
# plot the data as a line plot
fer_plot = fer_data.plot(y=['TotalFertilityRate',
                'F.15to19Years',
                'F.20to24Years',
                'F.25to29Years',
                'F.30to34Years',
                'F.35to39Years',
                'F.40to44Years',
                'F.45to49Years'])

# Get the legend object
legend = fer_plot.legend()

# Set the position of the legend outside the plot
legend.set_bbox_to_anchor((1.5, 1))

# display the plot
plt.show()

# %%
TotalFertilityRate = pd.DataFrame(fer_data['TotalFertilityRate'])

# %%
f, axes = plt.subplots(1, 3, figsize=(24, 8))

#BelowSecondary
sb.boxplot(data = TotalFertilityRate, orient = "h",ax = axes[0])
sb.histplot(data = TotalFertilityRate,ax = axes[1])
sb.violinplot(data = TotalFertilityRate, orient = "h",ax = axes[2])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exploring the Education Data
#
# In the dataset under analysis, we have explored the education of females, and observed a consistent increase in the number of females attaining degrees over the years. Our analysis will focus on examining the relationship between the highest qualification attained by females in Singapore and the corresponding birth rate.

# %%
edu_data = pd.read_pickle('EduFactor.pickle')
edu_data.head()
# Out:
#        TotalFertilityRate  BelowSecondary  Secondary  \
# Years
# 2022                 1.05        369800.0   271500.0
# 2021                 1.12        362700.0   281300.0
# 2020                 1.10        433400.0   269300.0
# 2019                 1.14        426500.0   282800.0
# 2018                 1.14        441500.0   285600.0
#
#        PostSecondary(NontoTertiary)  Diploma&ProfessionalQualification  \
# Years
# 2022                       147700.0                           265100.0
# 2021                       130000.0                           239000.0
# 2020                       138800.0                           226700.0
# 2019                       122400.0                           225700.0
# 2018                       117600.0                           215400.0
#
#        University
# Years
# 2022     552400.0
# 2021     534200.0
# 2020     496600.0
# 2019     470500.0
# 2018     440400.0

# %%
edu_data.describe().round(2)
# Out:
#        TotalFertilityRate  BelowSecondary  Secondary  \
# count               33.00           33.00      33.00
# mean                 1.37       504154.55  266930.30
# std                  0.23        53521.32   28134.79
# min                  1.05       362700.00  191800.00
# 25%                  1.20       469900.00  255900.00
# 50%                  1.28       524400.00  271900.00
# 75%                  1.60       545900.00  285100.00
# max                  1.83       563700.00  307700.00
#
#        PostSecondary(NontoTertiary)  Diploma&ProfessionalQualification  \
# count                         33.00                              33.00
# mean                       88203.03                          127387.88
# std                        27942.36                           74061.76
# min                        36700.00                           18900.00
# 25%                        70600.00                           61400.00
# 50%                        74000.00                          126400.00
# 75%                       110600.00                          198200.00
# max                       147700.00                          265100.00
#
#        University
# count       33.00
# mean    233893.94
# std     163563.91
# min      28900.00
# 25%      87500.00
# 50%     212700.00
# 75%     362400.00
# max     552400.00

# %%
# plot the data as a line plot
edu_plot = edu_data.plot(y=['BelowSecondary',
                 'Secondary',
                 'PostSecondary(NontoTertiary)',
                 'Diploma&ProfessionalQualification',
                 'University'])
# Get the legend object
legend = edu_plot.legend()

# Set the position of the legend outside the plot
legend.set_bbox_to_anchor((1.05, 1))

# display the plot
plt.show()

# %%
BelowSecondary = pd.DataFrame(edu_data['BelowSecondary'])
Secondary = pd.DataFrame(edu_data['Secondary'])
PostSecondary = pd.DataFrame({
    'PostSecondary(NontoTertiary)': edu_data['PostSecondary(NontoTertiary)'],
    'Diploma&ProfessionalQualification': edu_data['Diploma&ProfessionalQualification']
})
University = pd.DataFrame(edu_data['University'])

# %%
f, axes = plt.subplots(4, 3, figsize=(24, 12))

#BelowSecondary
sb.boxplot(data = BelowSecondary, orient = "h",ax = axes[0,0])
sb.histplot(data = BelowSecondary,ax = axes[0,1])
sb.violinplot(data = BelowSecondary, orient = "h",ax = axes[0,2])

#Secondary
sb.boxplot(data = Secondary, orient = "h",ax = axes[1,0])
sb.histplot(data = Secondary,ax = axes[1,1])
sb.violinplot(data = Secondary, orient = "h",ax = axes[1,2])

#PostSecondary
sb.boxplot(data = PostSecondary, orient = "h",ax = axes[2,0])
sb.histplot(data = PostSecondary,ax = axes[2,1])
sb.violinplot(data = PostSecondary, orient = "h",ax = axes[2,2])

#University
sb.boxplot(data = University, orient = "h",ax = axes[3,0])
sb.histplot(data = University,ax = axes[3,1])
sb.violinplot(data = University, orient = "h",ax = axes[3,2])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exploring the Cost of living Data
#
# In this dataset, we study the cost of living in Singapore and see the trends in the past years. We learned that the cost of living is increasing every year including our education cost, which could be one of the reason for lower fertility rate as it is more expensive to provide kids education.

# %%
CoL_data = pd.read_pickle('CoLFactor.pickle')
CoL_data
# Out:
#        TotalFertilityRate  AllItems    Food  Clothing&Footwear  \
# Years
# 2022                 1.05    108.37  108.81              93.42
# 2021                 1.12    102.12  103.33              90.84
# 2020                 1.10     99.82  101.86              96.16
# 2019                 1.14    100.00  100.00             100.00
# 2018                 1.14     99.44   98.50             100.78
# ...                   ...       ...     ...                ...
# 1965                 4.66     25.51   22.93              54.39
# 1964                 4.97     25.45   23.03              53.72
# 1963                 5.16     25.03   22.47              53.42
# 1962                 5.21     24.51   21.67              53.59
# 1961                 5.41     24.40   21.52              53.85
#
#        Housing&Utilities  HouseholdDurables&Services  \
# Years
# 2022              106.41                      103.84
# 2021              101.10                      101.77
# 2020               99.71                      100.28
# 2019              100.00                      100.00
# 2018              101.00                       99.23
# ...                  ...                         ...
# 1965               27.91                       32.34
# 1964               27.40                       31.57
# 1963               26.91                       31.50
# 1962               26.85                       32.15
# 1961               26.69                       32.11
#
#        HouseholdServices&Supplies  HealthCare  Transport  PrivateTransport  \
# Years
# 2022                   103.290000      101.75     125.79        130.960000
# 2021                   101.890000       99.58     108.06        109.900000
# 2020                   100.510000       98.46      99.27         98.640000
# 2019                   100.000000      100.00     100.00        100.000000
# 2018                    98.560000       98.90      99.24         99.680000
# ...                           ...         ...        ...               ...
# 1965                    31.757097       18.60      20.61         33.176452
# 1964                    31.757097       18.60      20.61         33.176452
# 1963                    31.757097       18.60      20.54         33.176452
# 1962                    31.757097       18.61      20.52         33.176452
# 1961                    31.757097       18.60      20.54         33.176452
#
#        ...  OtherTransportServices  Communication  Recreation&Culture  \
# Years  ...
# 2022   ...              113.600000          98.90              103.48
# 2021   ...              100.840000         100.10               99.23
# 2020   ...               96.940000         100.68               98.21
# 2019   ...              100.000000         100.00              100.00
# 2018   ...               99.260000         100.92               98.95
# ...    ...                     ...            ...                 ...
# 1965   ...               35.565806         133.73               49.12
# 1964   ...               35.565806          96.58               49.12
# 1963   ...               35.565806          89.16               49.08
# 1962   ...               35.565806          89.16               49.12
# 1961   ...               35.565806          89.16               49.12
#
#        Education  MiscellaneousGoods&Services  PersonalCare  \
# Years
# 2022      102.75                        98.74    100.140000
# 2021      100.63                        98.28     98.500000
# 2020       99.37                        98.82     99.950000
# 2019      100.00                       100.00    100.000000
# 2018       97.66                        99.64     99.300000
# ...          ...                          ...           ...
# 1965       15.22                        18.91     36.112581
# 1964       15.58                        18.59     36.112581
# 1963       15.41                        18.82     36.112581
# 1962       14.93                        18.83     36.112581
# 1961       14.87                        18.83     36.112581
#
#        AlcoholicDrinks&Tobacco  PersonalEffects  \
# Years
# 2022                   100.160        97.160000
# 2021                    98.950        96.430000
# 2020                    99.020        94.880000
# 2019                   100.000       100.000000
# 2018                    99.570       100.580000
# ...                        ...              ...
# 1965                    31.005        36.054032
# 1964                    31.005        36.054032
# 1963                    31.005        36.054032
# 1962                    31.005        36.054032
# 1961                    31.005        36.054032
#
#        AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation  \
# Years
# 2022                                          108.700000
# 2021                                          102.130000
# 2020                                           99.680000
# 2019                                          100.000000
# 2018                                           99.100000
# ...                                                  ...
# 1965                                           23.002742
# 1964                                           23.002742
# 1963                                           23.002742
# 1962                                           23.002742
# 1961                                           23.002742
#
#        AllItemsLessAccommodation
# Years
# 2022                  108.990000
# 2021                  102.200000
# 2020                   99.660000
# 2019                  100.000000
# 2018                   99.070000
# ...                          ...
# 1965                   32.769516
# 1964                   32.769516
# 1963                   32.769516
# 1962                   32.769516
# 1961                   32.769516
#
# [62 rows x 21 columns]

# %%
CoL_data.describe().round(2)
# Out:
#        TotalFertilityRate  AllItems    Food  Clothing&Footwear  \
# count               62.00     62.00   62.00              62.00
# mean                 2.04     63.46   60.21              83.31
# std                  1.16     25.43   24.72              15.32
# min                  1.05     24.40   21.52              53.42
# 25%                  1.27     42.44   42.59              76.94
# 50%                  1.64     65.63   59.77              88.56
# 75%                  2.04     78.84   73.87              94.50
# max                  5.41    108.37  108.81             100.78
#
#        Housing&Utilities  HouseholdDurables&Services  \
# count              62.00                       62.00
# mean               64.57                       70.85
# std                27.07                       21.48
# min                26.69                       31.50
# 25%                41.66                       58.01
# 50%                64.34                       77.17
# 75%                77.77                       84.09
# max               113.52                      103.84
#
#        HouseholdServices&Supplies  HealthCare  Transport  PrivateTransport  \
# count                       62.00       62.00      62.00             62.00
# mean                        51.73       53.27      60.33             54.05
# std                         27.09       27.78      29.33             29.04
# min                         31.76       18.60      20.52             33.18
# 25%                         31.76       26.73      31.71             33.18
# 50%                         31.76       51.89      65.71             33.18
# 75%                         77.06       74.45      76.76             75.60
# max                        103.29      101.75     125.79            130.96
#
#        ...  OtherTransportServices  Communication  Recreation&Culture  \
# count  ...                   62.00          62.00               62.00
# mean   ...                   57.94         117.44               76.38
# std    ...                   29.62          15.35               18.12
# min    ...                   35.57          89.16               49.08
# 25%    ...                   35.57         103.56               56.40
# 50%    ...                   35.57         116.85               84.02
# 75%    ...                   91.33         133.73               90.53
# max    ...                  113.60         139.20              103.48
#
#        Education  MiscellaneousGoods&Services  PersonalCare  \
# count      62.00                        62.00         62.00
# mean       45.65                        59.01         58.83
# std        29.17                        29.40         29.89
# min        14.87                        18.59         36.11
# 25%        17.50                        31.49         36.11
# 50%        39.44                        59.05         36.11
# 75%        68.02                        90.35         95.20
# max       102.75                       100.00        101.10
#
#        AlcoholicDrinks&Tobacco  PersonalEffects  \
# count                    62.00            62.00
# mean                     50.51            58.73
# std                      27.41            29.81
# min                      31.00            36.05
# 25%                      31.00            36.05
# 50%                      31.00            36.05
# 75%                      83.19            95.48
# max                     100.16           101.14
#
#        AllItemsLessImputedRentalsOnOwnertoOccupiedAccommodation  \
# count                                              62.00
# mean                                               40.44
# std                                                31.30
# min                                                23.00
# 25%                                                23.00
# 50%                                                23.00
# 75%                                                23.00
# max                                               108.70
#
#        AllItemsLessAccommodation
# count                      62.00
# mean                       53.38
# std                        27.84
# min                        32.77
# 25%                        32.77
# 50%                        32.77
# 75%                        78.89
# max                       108.99
#
# [8 rows x 21 columns]

# %%
# plot the data as a line plot
CoL_plot = CoL_data.plot(y=['AllItems',
                 'Food',
                 'Clothing&Footwear',
                 'Housing&Utilities',
                 'HouseholdDurables&Services',
                'HealthCare',
                'Transport',
                'Communication',
                'Recreation&Culture',
                'Education',
                 'MiscellaneousGoods&Services'])

# Get the legend object
legend = CoL_plot.legend()

# Set the position of the legend outside the plot
legend.set_bbox_to_anchor((1.05, 1))

# display the plot
plt.show()

# %%
All = pd.DataFrame(CoL_data['AllItems'])

Fertility = pd.DataFrame(CoL_data['TotalFertilityRate'])
Food = pd.DataFrame(CoL_data['Food'])
Clothing = pd.DataFrame(CoL_data['Clothing&Footwear'])
Household = pd.DataFrame({
    'Housing&Utilities': CoL_data['Housing&Utilities'],
    'HouseholdDurables&Services': CoL_data['HouseholdDurables&Services'],
    'HouseholdServices&Supplies' : CoL_data['HouseholdServices&Supplies']
})
Healthcare = pd.DataFrame(CoL_data['HealthCare'])
Transport = pd.DataFrame(CoL_data['Transport'])
Communication = pd.DataFrame(CoL_data['Communication'])
RecreationCulture = pd.DataFrame(CoL_data['Recreation&Culture'])
Education = pd.DataFrame(CoL_data['Education'])

# %%
f, axes = plt.subplots(8, 3, figsize=(24, 12))

#Food
sb.boxplot(data = Food, orient = "h",ax = axes[0,0])
sb.histplot(data = Food,ax = axes[0,1])
sb.violinplot(data = Food, orient = "h",ax = axes[0,2])

#Clothing
sb.boxplot(data = Clothing, orient = "h",ax = axes[1,0])
sb.histplot(data = Clothing,ax = axes[1,1])
sb.violinplot(data = Clothing, orient = "h",ax = axes[1,2])

#Household
sb.boxplot(data = Household, orient = "h",ax = axes[2,0])
sb.histplot(data = Household,ax = axes[2,1])
sb.violinplot(data = Household, orient = "h",ax = axes[2,2])

#Healthcare
sb.boxplot(data = Healthcare, orient = "h",ax = axes[3,0])
sb.histplot(data = Healthcare,ax = axes[3,1])
sb.violinplot(data = Healthcare, orient = "h",ax = axes[3,2])

#Transport
sb.boxplot(data = Transport, orient = "h",ax = axes[4,0])
sb.histplot(data = Transport,ax = axes[4,1])
sb.violinplot(data = Transport, orient = "h",ax = axes[4,2])

#Communication
sb.boxplot(data = Communication, orient = "h",ax = axes[5,0])
sb.histplot(data = Communication,ax = axes[5,1])
sb.violinplot(data = Communication, orient = "h",ax = axes[5,2])

#RecreationCulture
sb.boxplot(data = RecreationCulture, orient = "h",ax = axes[6,0])
sb.histplot(data = RecreationCulture,ax = axes[6,1])
sb.violinplot(data = RecreationCulture, orient = "h",ax = axes[6,2])

#Education
sb.boxplot(data = Education, orient = "h",ax = axes[7,0])
sb.histplot(data = Education,ax = axes[7,1])
sb.violinplot(data = Education, orient = "h",ax = axes[7,2])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exploring the Marriage Data

# %%
Mar_data = pd.read_pickle('MarFactor.pickle')
Mar_data.head()
# Out:
#        TotalFertilityRate  FemaleGeneralMarriageRate  M.15to19Years  \
# Years
# 2022                 1.05                       44.2            1.1
# 2021                 1.12                       34.9            1.2
# 2020                 1.10                       37.9            1.2
# 2019                 1.14                       40.8            1.2
# 2018                 1.14                       42.8            1.5
#
#        M.20to24Years  M.25to29Years  M.30to34Years  M.35to39Years  \
# Years
# 2022            18.8          100.9          106.4           49.0
# 2021            16.7           79.9           81.6           39.9
# 2020            16.4           88.6           95.5           46.8
# 2019            18.4           99.8          100.0           48.0
# 2018            19.8          108.8          101.6           51.2
#
#        M.40to44Years  M.45to49Years  M.50to54Years  M.55to59Years  \
# Years
# 2022            19.2            9.5            6.8            2.8
# 2021            17.3            9.1            5.6            2.6
# 2020            21.4           11.0            6.5            3.4
# 2019            22.0           12.1            6.3            2.8
# 2018            22.4           12.0            5.6            2.9
#
#        M.60to64Years  M.65Years&Over
# Years
# 2022             1.7             0.3
# 2021             1.3             0.2
# 2020             1.5             0.3
# 2019             1.5             0.2
# 2018             1.3             0.2

# %%
Mar_data.describe().round(2)
# Out:
#        TotalFertilityRate  FemaleGeneralMarriageRate  M.15to19Years  \
# count               42.00                      42.00          42.00
# mean                 1.43                      49.55           7.15
# std                  0.25                      10.40           5.17
# min                  1.05                      34.90           1.10
# 25%                  1.23                      40.28           2.45
# 50%                  1.39                      46.30           6.75
# 75%                  1.65                      58.85          10.78
# max                  1.96                      68.70          18.40
#
#        M.20to24Years  M.25to29Years  M.30to34Years  M.35to39Years  \
# count          42.00          42.00          42.00          42.00
# mean           55.62         117.91          81.00          39.49
# std            30.42          16.44          12.53           5.73
# min            16.40          79.90          59.20          29.20
# 25%            23.72         106.90          74.30          35.72
# 50%            52.90         114.45          76.70          38.35
# 75%            83.22         132.95          87.35          43.50
# max           110.50         151.00         106.50          51.20
#
#        M.40to44Years  M.45to49Years  M.50to54Years  M.55to59Years  \
# count          42.00          42.00          42.00          42.00
# mean           18.65           9.56           4.38           1.96
# std             2.60           1.50           1.18           0.70
# min            14.10           6.70           2.60           0.80
# 25%            16.82           8.52           3.40           1.30
# 50%            18.40           9.25           4.15           2.10
# 75%            20.60          10.35           5.48           2.60
# max            26.20          14.40           6.80           3.40
#
#        M.60to64Years  M.65Years&Over
# count          42.00           42.00
# mean            0.81            0.14
# std             0.40            0.08
# min             0.20            0.00
# 25%             0.60            0.10
# 50%             0.75            0.10
# 75%             1.08            0.20
# max             1.70            0.30

# %%
# plot the data as a line plot
Mar_plot = Mar_data.plot(y=['FemaleGeneralMarriageRate',
                 'M.15to19Years',
                 'M.20to24Years',
                 'M.25to29Years',
                 'M.30to34Years',
                 'M.35to39Years',
                 'M.40to44Years',
                 'M.45to49Years',
                 'M.50to54Years',
                 'M.55to59Years', ])
# Get the legend object
legend = Mar_plot.legend()

# Set the position of the legend outside the plot
legend.set_bbox_to_anchor((1.05, 1))

# display the plot
plt.show()

# %%
FemaleGeneralMarriageRate = pd.DataFrame(Mar_data['FemaleGeneralMarriageRate'])

# %%
f, axes = plt.subplots(1, 3, figsize=(20,5))

#FemaleGeneralMarriageRate
sb.boxplot(data = FemaleGeneralMarriageRate, orient = "h",ax = axes[0])
sb.histplot(data = FemaleGeneralMarriageRate,ax = axes[1])
sb.violinplot(data = FemaleGeneralMarriageRate, orient = "h",ax = axes[2])
# Out:
# <AxesSubplot:>
